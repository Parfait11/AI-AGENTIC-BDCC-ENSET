# %%
import tiktoken

def num_tokens_from_string(string: str, encoding_name: str = "o200k_base") -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    return len(encoding.encode(string))


encoding = tiktoken.encoding_for_model("gpt-4o")
print("Encoding utilise:", encoding.name)

system_message = """
Perform Sentiment analysis of the review presented in the user message.
The result should be positive or negative.
Do not justify your response.
"""

tokens = encoding.encode(system_message)

print("Nombre de tokens du prompt system:", len(tokens))
print("Liste des tokens:", tokens)
print("Reconstruction token par token:")
for token in tokens:
    print(encoding.decode_single_token_bytes(token).decode("utf-8", errors="ignore"), end="")

print("\n")
print("Exemple simple:", num_tokens_from_string("tiktoken is great!"))
# Out:
# Encoding utilise: o200k_base
# Nombre de tokens du prompt system: 28
# Liste des tokens: [198, 73751, 31712, 2581, 8450, 328, 290, 3358, 13392, 306, 290, 1825, 3176, 558, 976, 1534, 1757, 413, 8841, 503, 12626, 558, 6449, 625, 14883, 634, 3322, 558]
# Reconstruction token par token:
#
# Perform Sentiment analysis of the review presented in the user message.
# The result should be positive or negative.
# Do not justify your response.
#
#
# Exemple simple: 6

# %%
import os

from dotenv import load_dotenv
from langchain_ollama import ChatOllama


load_dotenv()

model_name = os.getenv("OLLAMA_MODEL", "llama3.2:3b")

llm = ChatOllama(model=model_name, temperature=0)

response = llm.invoke(
    [
        {"role": "system", "content": "You are a helpful assistant. The output should be in Markdown."},
        {"role": "user", "content": "C'est quoi un Agent AI ?"},
    ]
)

print(response.content)
# Out:
# **Qu'est-ce qu'un Agent AI ?**
#
# Un agent AI (Artificial Intelligence) est un programme informatique conçu pour simuler des comportements humains ou pour résoudre des problèmes complexes de manière autonome. Il s'agit d'une entité qui peut prendre des décisions, apprendre et s'adapter à son environnement.
#
# **Caractéristiques d'un Agent AI**
#
# Un agent AI possède les suivantes caractéristiques :
#
# *   **Connaissance de l'environnement** : L'agent a une compréhension de son environnement et peut y naviguer pour collecter des informations.
# *   **Objectifs** : L'agent a des objectifs à atteindre, qui peuvent être définis par son créateur ou découverts automatiquement.
# *   **Actions** : L'agent peut prendre des actions pour atteindre ses objectifs.
# *   **Apprentissage** : L'agent peut apprendre à partir de l'environnement et des expériences.
#
# **Types d'Agents AI**
#
# Il existe plusieurs types d'agents AI, notamment :
#
# 1.  **Agent réactif** : L'agent réagit aux stimuli de son environnement pour atteindre ses objectifs.
# 2.  **Agent planificateur** : L'agent planifie ses actions pour atteindre ses objectifs.
# 3.  **Agent apprenant** : L'agent apprend à partir de l'environnement et des expériences.
#
# **Exemples d'Agents AI**
#
# *   **Chatbots** : Les chatbots sont des agents AI qui utilisent le langage naturel pour répondre aux questions des utilisateurs.
# *   **Voitures autonomes** : Les voitures autonomes sont des agents AI qui utilisent la vision et l'apprentissage pour naviguer sur les routes.
# *   **Assistants virtuels** : Les assistants virtuels, tels que Siri ou Alexa, sont des agents AI qui utilisent le langage naturel pour répondre aux questions des utilisateurs.
#
# En résumé, un agent AI est un programme informatique conçu pour simuler des comportements humains ou pour résoudre des problèmes complexes de manière autonome. Il possède les caractéristiques de la connaissance de l'environnement, des objectifs et des actions, et peut apprendre à partir de l'environnement et des expériences.

# %%
from dotenv import load_dotenv
from langchain_groq import ChatGroq
from langchain.messages import HumanMessage, SystemMessage


load_dotenv(override=True)

llm = ChatGroq(model="openai/gpt-oss-120b", temperature=0)

response = llm.invoke(
    [
        SystemMessage(content="You are a helpful assistant. The output should be in Markdown."),
        HumanMessage(content="C'est quoi un Agent AI ?"),
    ]
)

print(response.content)
# Out:
# ## Qu’est‑ce qu’un **Agent IA** ?
#
# Un **agent d’intelligence artificielle (IA)** est un système logiciel capable d’interagir avec son environnement, de percevoir des informations, de prendre des décisions et d’agir en conséquence, le tout de façon autonome ou semi‑autonome.
#
# ### 1. Principes de base
#
# | Élément | Description |
# |---------|-------------|
# | **Perception** | L’agent reçoit des données (capteurs, API, texte, images, etc.) qui décrivent l’état du monde extérieur ou d’un environnement virtuel. |
# | **Modélisation** | Il construit ou met à jour un modèle interne (représentation) de cet environnement (ex. carte, état du jeu, contexte conversationnel). |
# | **Raisonnement / Décision** | À partir du modèle, il choisit une action en fonction d’un objectif (maximiser une récompense, atteindre un but, répondre à une question). |
# | **Action** | L’agent exécute l’action choisie (envoi d’un message, déplacement d’un robot, modification d’un fichier, etc.). |
# | **Apprentissage (optionnel)** | Il ajuste ses stratégies ou son modèle à partir de l’expérience (reinforcement learning, apprentissage supervisé, etc.). |
#
# ### 2. Types d’agents IA
#
# | Type d’agent | Caractéristiques | Exemples concrets |
# |--------------|------------------|-------------------|
# | **Agent réactif** | Réagit immédiatement aux stimuli sans mémoire à long terme. | Systèmes de contrôle de trafic, bots de jeu qui répondent aux mouvements du joueur. |
# | **Agent basé sur le modèle** | Construit une représentation interne du monde et planifie. | Robots de navigation qui utilisent une carte, assistants vocaux qui maintiennent le contexte d’une conversation. |
# | **Agent délibératif** | Utilise un raisonnement logique ou symbolique pour planifier plusieurs étapes. | Systèmes de planification de missions spatiales, IA de résolution de puzzles. |
# | **Agent d’apprentissage** | Améliore ses performances grâce à l’expérience (RL, apprentissage supervisé). | AlphaGo, agents de trading automatisés, chatbots qui s’ajustent aux retours utilisateurs. |
# | **Agent hybride** | Combine plusieurs des approches ci‑dessus (ex. réactif + apprentissage). | Voitures autonomes (perception réactive + planification à long terme + apprentissage continu). |
#
# ### 3. Architecture typique d’un agent IA
#
# ```mermaid
# graph LR
#     A[Capteurs / Entrées] --> B[Perception & Pré‑traitement]
#     B --> C[Modèle interne / Mémoire]
#     C --> D[Module de décision / Politique]
#     D --> E[Action / Effecteur]
#     E --> F[Environnement]
#     F --> A
#     D --> G[Apprentissage (optionnel)]
#     G --> C
# ```
#
# * **Capteurs / Entrées** : données brutes (texte, audio, images, mesures physiques).
# * **Perception** : filtrage, extraction de caractéristiques, reconnaissance d’objets, NLP, etc.
# * **Modèle interne** : état du monde, historique, réseaux de neurones, bases de connaissances.
# * **Décision** : algorithmes de recherche, réseaux de neurones, fonctions de valeur, règles logiques.
# * **Action** : commandes, réponses textuelles, mouvements, transactions.
# * **Apprentissage** : mise à jour des poids du réseau, ajustement de la politique, mise à jour de la base de règles.
#
# ### 4. Exemples d’agents IA dans la vie quotidienne
#
# | Domaine | Agent IA | Fonction principale |
# |--------|----------|----------------------|
# | **Assistants vocaux** | Siri, Google Assistant, Alexa | Comprendre le langage naturel, exécuter des tâches (alarme, recherche, contrôle domotique). |
# | **Jeux vidéo** | NPCs (personnages non‑joueurs) intelligents | Décider de stratégies, réagir aux actions du joueur. |
# | **Robots domestiques** | Roomba, robot de cuisine | Cartographier la maison, planifier le nettoyage, éviter les obstacles. |
# | **Finance** | Algorithmes de trading haute fréquence | Analyser les marchés, placer des ordres automatiquement. |
# | **Santé** | Chatbots de triage (ex. Babylon) | Poser des questions, évaluer les symptômes, orienter vers un professionnel. |
#
# ### 5. Pourquoi parler d’« agent » ?
#
# Le terme **agent** met l’accent sur l’autonomie et la capacité d’interaction. Contrairement à un simple programme qui exécute une tâche fixe, un agent :
#
# 1. **Perçoit** son environnement.
# 2. **Agit** de façon adaptée.
# 3. **Poursuit** un ou plusieurs objectifs (maximiser une récompense, satisfaire un utilisateur, etc.).
# 4. **Peut apprendre** et s’améliorer avec le temps.
#
# ### 6. Points de vigilance
#
# | Risque / Limite | Description |
# |-----------------|-------------|
# | **Biais** | Si les données d’entraînement sont biaisées, l’agent reproduira ces biais. |
# | **Transparence** | Les décisions d’un agent basé sur un réseau de neurones profond sont souvent opaques (« boîte noire »). |
# | **Sécurité** | Un agent mal conçu peut prendre des actions dangereuses (ex. robot industriel). |
# | **Éthique** | Utilisation responsable (vie privée, consentement, impact sociétal). |
#
# ---
#
# ## En résumé
#
# Un **agent IA** est un système capable de **percevoir**, **raisonner**, **agir** et, souvent, **apprendre** pour atteindre des objectifs dans un environnement donné. Selon la complexité du problème, on utilise des agents simples réactifs ou des agents très sophistiqués combinant planification, apprentissage et interaction en temps réel. Ils sont aujourd’hui omniprésents, des assistants vocaux aux voitures autonomes, et continueront de jouer un rôle central dans la transformation numérique.

# %%
from dotenv import load_dotenv
from langchain_ollama import ChatOllama


load_dotenv(override=True)

model = ChatOllama(model="llama3.2:3b", temperature=0)

response = model.invoke(
    [
        {"role": "system", "content": "You are a helpful assistant. The output should be in Markdown."},
        {"role": "user", "content": "C'est quoi un Agent AI ?"},
    ]
)

print(response.content)
# Out:
# **Qu'est-ce qu'un Agent AI ?**
#
# Un agent AI (Artificial Intelligence) est un programme informatique conçu pour simuler des comportements humains ou pour résoudre des problèmes complexes de manière autonome. Il s'agit d'une entité qui peut prendre des décisions, apprendre et s'adapter à son environnement.
#
# **Caractéristiques d'un Agent AI**
#
# Un agent AI possède les suivantes caractéristiques :
#
# *   **Connaissance de l'environnement** : L'agent a une compréhension de son environnement et peut y naviguer pour collecter des informations.
# *   **Objectifs** : L'agent a des objectifs à atteindre, qui peuvent être définis par son créateur ou découverts automatiquement.
# *   **Actions** : L'agent peut prendre des actions pour atteindre ses objectifs.
# *   **Apprentissage** : L'agent peut apprendre à partir de l'environnement et des expériences.
#
# **Types d'Agents AI**
#
# Il existe plusieurs types d'agents AI, notamment :
#
# 1.  **Agent réactif** : L'agent réagit aux stimuli de son environnement pour atteindre ses objectifs.
# 2.  **Agent planificateur** : L'agent planifie ses actions pour atteindre ses objectifs.
# 3.  **Agent apprenant** : L'agent apprend à partir de l'environnement et des expériences.
#
# **Exemples d'Agents AI**
#
# *   **Chatbots** : Les chatbots sont des agents AI qui utilisent le langage naturel pour répondre aux questions des utilisateurs.
# *   **Voitures autonomes** : Les voitures autonomes sont des agents AI qui utilisent la vision et l'apprentissage pour naviguer sur les routes.
# *   **Assistants virtuels** : Les assistants virtuels, tels que Siri ou Alexa, sont des agents AI qui utilisent le langage naturel pour répondre aux questions des utilisateurs.
#
# En résumé, un agent AI est un programme informatique conçu pour simuler des comportements humains ou pour résoudre des problèmes complexes de manière autonome. Il possède les caractéristiques de la connaissance de l'environnement, des objectifs et des actions, et peut apprendre à partir de l'environnement et des expériences.

# %%
import json

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI


load_dotenv(override=True)

system_message = """
Effectuez une analyse de sentiments basee sur les aspects des avis concernant
les ordinateurs portables presentes en entree.

Chaque avis peut comporter un ou plusieurs des aspects suivants : screen,
keyboard et pad.

Pour chaque avis presente en entree :
- Identifiez la presence d'au moins un des trois aspects.
- Attribuez une polarite de sentiment (positive, negative ou neutral)
  a chaque aspect.
- Organisez votre reponse dans un objet JSON avec les cles suivantes :
  - category : liste des aspects
  - polarity : liste des polarites correspondantes
- Si l'un des aspects n'est pas present dans l'avis, supposez que sa
  polarite est neutral.
"""

llm = ChatOpenAI(
    model="gpt-5.2",
    temperature=0,
    model_kwargs={"response_format": {"type": "json_object"}},
)

resp = llm.invoke(
    [
        {"role": "system", "content": system_message},
        {
            "role": "user",
            "content": "L'ecran est tres bon, mais je n'ai pas aime le pad. Le clavier est acceptable.",
        },
    ]
)

print(resp.content)

result = json.loads(resp.content)
print("\nJSON parse:", result)
print("Premiere polarite:", result["polarity"][0])
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[30], line 33
#      29     temperature=0,
#      30     model_kwargs={"response_format": {"type": "json_object"}},
#      31 )
#      32
# ---> 33 resp = llm.invoke(
#      34     [
#      35         {"role": "system", "content": system_message},
#      36         {
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1692, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1690     _handle_openai_bad_request(e)
#    1691 except openai.APIError as e:
# -> 1692     _handle_openai_api_error(e)
#    1693 except Exception as e:
#    1694     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1664, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1661 if "response_format" in payload:
#    1662     payload.pop("stream")
#    1663     raw_response = (
# -> 1664         self.root_client.chat.completions.with_raw_response.parse(**payload)
#    1665     )
#    1666     response = raw_response.parse()
#    1667 elif self._use_responses_api(payload):
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:192, in Completions.parse(self, messages, model, audio, response_format, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, safety_identifier, seed, service_tier, stop, store, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     185 def parser(raw_completion: ChatCompletion) -> ParsedChatCompletion[ResponseFormatT]:
#     186     return _parse_chat_completion(
#     187         response_format=response_format,
#     188         chat_completion=raw_completion,
#     189         input_tools=chat_completion_tools,
#     190     )
# --> 192 return self._post(
#     193     "/chat/completions",
#     194     body=maybe_transform(
#     195         {
#     196             "messages": messages,
#     197             "model": model,
#     198             "audio": audio,
#     199             "frequency_penalty": frequency_penalty,
#     200             "function_call": function_call,
#     201             "functions": functions,
#     202             "logit_bias": logit_bias,
#     203             "logprobs": logprobs,
#     204             "max_completion_tokens": max_completion_tokens,
#     205             "max_tokens": max_tokens,
#     206             "metadata": metadata,
#     207             "modalities": modalities,
#     208             "moderation": moderation,
#     209             "n": n,
#     210             "parallel_tool_calls": parallel_tool_calls,
#     211             "prediction": prediction,
#     212             "presence_penalty": presence_penalty,
#     213             "prompt_cache_key": prompt_cache_key,
#     214             "prompt_cache_retention": prompt_cache_retention,
#     215             "reasoning_effort": reasoning_effort,
#     216             "response_format": _type_to_response_format(response_format),
#     217             "safety_identifier": safety_identifier,
#     218             "seed": seed,
#     219             "service_tier": service_tier,
#     220             "stop": stop,
#     221             "store": store,
#     222             "stream": False,
#     223             "stream_options": stream_options,
#     224             "temperature": temperature,
#     225             "tool_choice": tool_choice,
#     226             "tools": tools,
#     227             "top_logprobs": top_logprobs,
#     228             "top_p": top_p,
#     229             "user": user,
#     230             "verbosity": verbosity,
#     231             "web_search_options": web_search_options,
#     232         },
#     233         completion_create_params.CompletionCreateParams,
#     234     ),
#     235     options=make_request_options(
#     236         extra_headers=extra_headers,
#     237         extra_query=extra_query,
#     238         extra_body=extra_body,
#     239         timeout=timeout,
#     240         post_parser=parser,
#     241         security={"bearer_auth": True},
#     242     ),
#     243     # we turn the `ChatCompletion` instance into a `ParsedChatCompletion`
#     244     # in the `parser` function above
#     245     cast_to=cast(Type[ParsedChatCompletion[ResponseFormatT]], ChatCompletion),
#     246     stream=False,
#     247 )
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
import base64

from dotenv import load_dotenv
from langchain.messages import HumanMessage
from langchain_openai import ChatOpenAI


load_dotenv(override=True)

llm = ChatOpenAI(model="gpt-5.2")
llm_with_tools = llm.bind_tools([{"type": "image_generation", "quality": "high"}])

response = llm_with_tools.invoke(
    [HumanMessage(content="Je veux une photo d'un chat qui code du Java.")]
)

image_block = response.content_blocks[0]
image_bytes = base64.b64decode(image_block["base64"])

with open("generated_cat_java.png", "wb") as output_file:
    output_file.write(image_bytes)

print("Image generee: generated_cat_java.png")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[31], line 13
#       9
#      10 llm = ChatOpenAI(model="gpt-5.2")
#      11 llm_with_tools = llm.bind_tools([{"type": "image_generation", "quality": "high"}])
#      12
# ---> 13 response = llm_with_tools.invoke(
#      14     [HumanMessage(content="Je veux une photo d'un chat qui code du Java.")]
#      15 )
#      16
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\runnables\base.py:6004, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5997 @override
#    5998 def invoke(
#    5999     self,
#    (...)   6002     **kwargs: Any | None,
#    6003 ) -> Output:
# -> 6004     return self.bound.invoke(
#    6005         input,
#    6006         self._merge_configs(config),
#    6007         **{**self.kwargs, **kwargs},
#    6008     )
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1692, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1690     _handle_openai_bad_request(e)
#    1691 except openai.APIError as e:
# -> 1692     _handle_openai_api_error(e)
#    1693 except Exception as e:
#    1694     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1674, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1670     raw_response = self.root_client.responses.with_raw_response.parse(
#    1671         **payload
#    1672     )
#    1673 else:
# -> 1674     raw_response = self.root_client.responses.with_raw_response.create(
#    1675         **payload
#    1676     )
#    1677 response = raw_response.parse()
#    1678 if self.include_response_headers:
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\resources\responses\responses.py:954, in Responses.create(self, background, context_management, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, moderation, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     914 def create(
#     915     self,
#     916     *,
#    (...)    952     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     953 ) -> Response | Stream[ResponseStreamEvent]:
# --> 954     return self._post(
#     955         "/responses",
#     956         body=maybe_transform(
#     957             {
#     958                 "background": background,
#     959                 "context_management": context_management,
#     960                 "conversation": conversation,
#     961                 "include": include,
#     962                 "input": input,
#     963                 "instructions": instructions,
#     964                 "max_output_tokens": max_output_tokens,
#     965                 "max_tool_calls": max_tool_calls,
#     966                 "metadata": metadata,
#     967                 "model": model,
#     968                 "moderation": moderation,
#     969                 "parallel_tool_calls": parallel_tool_calls,
#     970                 "previous_response_id": previous_response_id,
#     971                 "prompt": prompt,
#     972                 "prompt_cache_key": prompt_cache_key,
#     973                 "prompt_cache_retention": prompt_cache_retention,
#     974                 "reasoning": reasoning,
#     975                 "safety_identifier": safety_identifier,
#     976                 "service_tier": service_tier,
#     977                 "store": store,
#     978                 "stream": stream,
#     979                 "stream_options": stream_options,
#     980                 "temperature": temperature,
#     981                 "text": text,
#     982                 "tool_choice": tool_choice,
#     983                 "tools": tools,
#     984                 "top_logprobs": top_logprobs,
#     985                 "top_p": top_p,
#     986                 "truncation": truncation,
#     987                 "user": user,
#     988             },
#     989             response_create_params.ResponseCreateParamsStreaming
#     990             if stream
#     991             else response_create_params.ResponseCreateParamsNonStreaming,
#     992         ),
#     993         options=make_request_options(
#     994             extra_headers=extra_headers,
#     995             extra_query=extra_query,
#     996             extra_body=extra_body,
#     997             timeout=timeout,
#     998             security={"bearer_auth": True},
#     999         ),
#    1000         cast_to=Response,
#    1001         stream=stream or False,
#    1002         stream_cls=Stream[ResponseStreamEvent],
#    1003     )
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\ENSET MOHAMMEDIA\MASTER 1\IA\Lab_1-Ingenierie_des_prompts\.venv\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
import base64

from dotenv import load_dotenv
from langchain.messages import HumanMessage
from langchain_openai import ChatOpenAI


def encode_image(image_path: str) -> str:
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


load_dotenv(override=True)

image_path = "rag.png"
img = encode_image(image_path)

llm = ChatOpenAI(model="gpt-5.2")

response = llm.invoke(
    [
        HumanMessage(
            content=[
                {"type": "text", "text": "Qu'est-ce que tu vois dans cette image ?"},
                {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{img}"}},
            ]
        )
    ]
)

print(response.content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 16
#      12
#      13 load_dotenv(override=True)
#      14
#      15 image_path = "rag.png"
# ---> 16 img = encode_image(image_path)
#      17
#      18 llm = ChatOpenAI(model="gpt-5.2")
#      19
#
# Cell In[29], line 9, in encode_image(image_path)
#       8 def encode_image(image_path: str) -> str:
# ----> 9     with open(image_path, "rb") as image_file:
#      10         return base64.b64encode(image_file.read()).decode("utf-8")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'rag.png'
